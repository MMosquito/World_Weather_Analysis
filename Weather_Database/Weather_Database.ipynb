# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-90.000, 90.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip (lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(-75.94284644740266, -5.021968110849841), (-88.90502354816417, 71.55265547322793), (-55.554498081767065, 78.54687850516967), (14.28924554068874, -34.08341620031338), (27.610829270697835, 47.9405138439202), (-30.43138159585839, 57.070042948460724), (18.67133434702349, 81.97107286209965), (-34.03133982180158, -13.808490056339934), (-58.82676646998409, 27.18974973172473), (58.156871536686566, -56.73828916182025), (-28.229246715953906, 31.121081809314063), (-55.59054309274355, 83.99500565960597), (67.28839979784024, 86.24791192986305), (9.889138025889153, 48.204056421846275), (-60.457396739780535, -48.81756490360966), (-37.200306072314156, 49.16845361004579), (-33.77964309912249, -67.26657637676126), (-55.393565564472254, 86.00827570892898), (-19.830676271915507, -59.844402956580986), (54.456317796696226, 51.5973803924073), (32.650351868019825, -24.845505510944278), (-30.16724844624838, -25.01882567876065), (84.47606440900793, 39.65913524862313), (-75.83380867148706, 37.77314224779742), (19.958843877364274, -65.52965071573651), (78.98668279386504, 14.98730421866047), (-29.035633045322207, -38.39421522144259), (29.418589865652535, -56.05216845336358), (75.03908358620151, -50.37205151787209), (-69.5477382557825, 31.579224269960392), (77.58144297567281, -55.08985347088949), (-38.18074218418066, 44.86693052857166), (-28.73953094973964, -23.02200410900906), (-70.7502056818357, -35.26347084673312), (-86.33469513381839, -60.63138559935335), (35.159090844308594, -57.210285314139085), (75.85928054873892, 49.47061080863236), (-26.658995267171598, 77.64940989681), (75.46168962673158, 51.41914405783214), (79.59996820936311, -74.40788738192289), (-4.927510151135593, 34.862972036725395), (-15.57522395068375, 83.37167240222229), (-53.08008849292057, -35.754068071679995), (-24.11957906703742, 72.18793151542056), (25.125638047947973, 58.15215928558166), (65.35245906508297, -53.9192822675701), (28.791765823004596, -21.599507960571984), (83.89599446838008, -42.89269151250098), (-37.73455611795833, 36.00355227276849), (-81.66981426364462, 1.655375329548292), (-58.33597024004999, -57.57305930032452), (-43.40799550962685, -43.162554544178406), (-15.413114076968924, 80.75077260809499), (32.40377442033163, -68.33339511480138), (8.734666334390027, -75.64277198672724), (-44.66154667404885, 20.056111176376263), (-20.146637915670667, 9.567134779243574), (68.26403012759198, -89.26055095485933), (49.29040900449425, -58.39560635608023), (35.24990242132158, 67.71930077464955), (84.21397120565675, -47.516224238565755), (-27.816196397157867, 9.568701392478744), (60.558528984307515, -36.05193644945474), (-37.99392494322165, 55.62962197240691), (38.671449111191095, -63.196471149451156), (-21.355547190550567, -7.458317093241959), (84.71243882954164, 21.47688841988912), (-61.69334636992147, -15.979986729149147), (-44.272521505742894, -81.16669707756809), (-52.25454174141179, 31.83469927056555), (-20.594059858030718, 79.2372908460305), (41.689593029405586, 26.944884285091348), (75.44125481828303, 72.18721902901964), (38.99225455283795, -24.113547257556434), (62.006430222180484, -68.25519055139803), (20.35522388630723, 6.795929773593002), (-13.363912573004058, -37.512297839520414), (-79.48260453692367, -62.73429574864139), (-66.23841105091387, 18.801209822108802), (2.182601902044226, 24.303689567733414), (-58.76431188856827, 23.416055297024187), (-82.62767278306902, 75.12104733712462), (29.137850327205882, -66.86042470921296), (-13.354567176675815, 58.07097221679007), (-33.287611298881096, -30.482965838485505), (82.0505156940975, 18.759533774728325), (-64.93798467079097, 66.04673389192016), (13.951326470051242, 51.21382374175144), (3.499549100247151, -75.30253463834089), (-74.57510302444186, 88.92986928458794), (65.83142187192328, 69.88199801392955), (43.02767318175995, 36.15585362491238), (-82.0092654758344, 6.423434751273589), (69.94462814868595, 66.10674409089961), (64.65319019260704, -29.87691078681455), (-31.378252807264573, 1.8220785659810304), (87.80541476909039 ...

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 766

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
                                            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max_Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind, 
                         "Country": city_weather,
                         "Weather Description": description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | porto novo
# Processing Record 5 of Set 1 | bayan
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | malkangiri
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | kruisfontein
# Processing Record 10 of Set 1 | saint anthony
# Processing Record 11 of Set 1 | ulundi
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | igarka
# Processing Record 14 of Set 1 | garowe
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | san luis
# Processing Record 17 of Set 1 | mayor pablo lagerenza
# Processing Record 18 of Set 1 | shentala
# Processing Record 19 of Set 1 | vila franca do campo
# Processing Record 20 of Set 1 | vila velha
# Processing Record 21 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | loiza
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | saint george
# Processing Record 27 of Set 1 | ilulissat
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 1 | qaanaaq
# Processing Record 34 of Set 1 | mungaa
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | muscat
# Processing Record 38 of Set 1 | maniitsoq
# Processing Record 39 of Set 1 | los llanos de aridane
# Processing Record 40 of Set 1 | margate
# Processing Record 41 of Set 1 | hamilton
# Processing Record 42 of Set 1 | san carlos
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | opuwo
# Processing Record 45 of Set 1 | thompson
# Processing Record 46 of Set 1 | corner brook
# Processing Record 47 of Set 1 | gardan diwal
# City not found. Skipping...
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | shelburne
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | babaeski
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | iqaluit
# Processing Record 6 of Set 2 | arlit
# Processing Record 7 of Set 2 | salvador
# Processing Record 8 of Set 2 | buta
# Processing Record 9 of Set 2 | cap malheureux
# Processing Record 10 of Set 2 | bereda
# Processing Record 11 of Set 2 | ataco
# Processing Record 12 of Set 2 | yar-sale
# Processing Record 13 of Set 2 | sinop
# Processing Record 14 of Set 2 | sovetskiy
# Processing Record 15 of Set 2 | olafsvik
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 2 | raudeberg
# Processing Record 18 of Set 2 | xacmaz
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | cochrane
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | loveland
# Processing Record 23 of Set 2 | faro
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | chissamba
# Processing Record 26 of Set 2 | awjilah
# Processing Record 27 of Set 2 | faya
# Processing Record 28 of Set 2 | stephenville
# Processing Record 29 of Set 2 | camabatela
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | aromashevo
# Processing Record 32 of Set 2 | rio gallegos
# Processing Record 33 of Set 2 | liepaja
# Processing Record 34 of Set 2 | bauchi
# Processing Record 35 of Set 2 | georgetown
# Processing Record 36 of Set 2 | sao raimundo nonato
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | santo antonio do monte
# Processing Record 39 of Set 2 | hualmay
# Processing Record 40 of Set 2 | kalamb
# Processing Record 41 of Set 2 | bolshiye uki
# City not found. Skipping...
# Processing Record 42 of Set 2 | rodrigues alves
# Processing Record 43 of Set 2 | rancho veloz
# Processing Record 44 of Set 2 | sakmara
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | san isidro
# Processing Record 47 of Set 2 | paucartambo
# City not found. Skipping...
# Processing Record 48 of Set 2 | valdepenas
# Processing Record 49 of Set 2 | adrar
# Processing Record 50 of Set 2 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 3 | plettenberg bay
# Processing Record 2 of Set 3 | bonthe
# Processing Record 3 of Set 3 | punta arenas
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | sao filipe
# Processing Record 6 of Set 3 | itarema
# Processing Record 7 of Set 3 | zuwarah
# Processing Record 8 of Set 3 | floral park
# Processing Record 9 of Set 3 | oistins
# Processing Record 10 of Set 3 | obo
# Processing Record 11 of Set 3 | lebu
# Processing Record 12 of Set 3 | wawa
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | husavik
# Processing Record 15 of Set 3 | mar del plata
# Processing Record 16 of Set 3 | gorshechnoye
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | angoche
# Processing Record 19 of Set 3 | atbasar
# Processing Record 20 of Set 3 | paita
# Processing Record 21 of Set 3 | porbandar
# Processing Record 22 of Set 3 | ponta delgada
# Processing Record 23 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 3 | caravelas
# Processing Record 25 of Set 3 | muisne
# Processing Record 26 of Set 3 | joshimath
# Processing Record 27 of Set 3 | praia da vitoria
# Processing Record 28 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 3 | azuaga
# Processing Record 30 of Set 3 | uyuni
# Processing Record 31 of Set 3 | kostyantynivka
# Processing Record 32 of Set 3 | bloomingdale
# Processing Record 33 of Set 3 | torbay
# Processing Record 34 of Set 3 | ilebo
# Processing Record 35 of Set 3 | guarapari
# Processing Record 36 of Set 3 | limon
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | hwange
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | mysliborz
# Processing Record 41 of Set 3 | saint-joseph
# Processing Record 42 of Set 3 | cockburn town
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | hurghada
# Processing Record 45 of Set 3 | jiwani
# Processing Record 46 of Set 3 | banyo
# Processing Record 47 of Set 3 | nokaneng
# Processing Record 48 of Set 3 | cravo norte
# Processing Record 49 of Set 3 | luba
# Processing Record 50 of Set 3 | iracoubo
# Processing Record 1 of Set 4 | la sierra
# Processing Record 2 of Set 4 | loubomo
# Processing Record 3 of Set 4 | lewisville
# Processing Record 4 of Set 4 | krasnoselkup
# Processing Record 5 of Set 4 | verkhnyaya inta
# Processing Record 6 of Set 4 | tibati
# Processing Record 7 of Set 4 | pirajui
# Processing Record 8 of Set 4 | kumluca
# Processing Record 9 of Set 4 | ellisras
# Processing Record 10 of Set 4 | pinega
# Processing Record 11 of Set 4 | dudinka
# Processing Record 12 of Set 4 | belmonte
# Processing Record 13 of Set 4 | necochea
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | carire
# Processing Record 16 of Set 4 | pangnirtung
# Processing Record 17 of Set 4 | nioro
# Processing Record 18 of Set 4 | oktyabrskoye
# Processing Record 19 of Set 4 | chicama
# Processing Record 20 of Set 4 | eydhafushi
# Processing Record 21 of Set 4 | santa cruz
# Processing Record 22 of Set 4 | itaituba
# Processing Record 23 of Set 4 | bonfim
# Processing Record 24 of Set 4 | touros
# Processing Record 25 of Set 4 | pangoa
# Processing Record 26 of Set 4 | zambezi
# Processing Record 27 of Set 4 | pokaran
# Processing Record 28 of Set 4 | jalu
# Processing Record 29 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 4 | abu samrah
# Processing Record 31 of Set 4 | pohrebyshche
# Processing Record 32 of Set 4 | mogadishu
# Processing Record 33 of Set 4 | reserva
# Processing Record 34 of Set 4 | porto de moz
# Processing Record 35 of Set 4 | cumberland
# Processing Record 36 of Set 4 | talnakh
# Processing Record 37 of Set 4 | atasu
# Processing Record 38 of Set 4 | constitucion
# Processing Record 39 of Set 4 | cururupu
# Processing Record 40 of Set 4 | vuktyl
# Processing Record 41 of Set 4 | ajdabiya
# Processing Record 42 of Set 4 | falkoping
# City not found. Skipping...
# Processing Record 43 of Set 4 | nioaque
# Processing Record 44 of Set 4 | pauini
# Processing Record 45 of Set 4 | ribeira grande
# Processing Record 46 of Set 4 | sao felix do xingu
# Processing Record 47 of Set 4 | kirkenaer
# Processing Record 48 of Set 4 | mokhotlong
# Processing Record 49 of Set 4 | antalaha
# Processing Record 50 of Set 4 | suda
# Processing Record 1 of Set 5 | shihezi
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | mayahi
# Processing Record 4 of Set 5 | victoria
# Processing Record 5 of Set 5 | erzincan
# Processing Record 6 of Set 5 | tornio
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | san cristobal
# Processing Record 9 of Set 5 | bandarbeyla
# Processing Record 10 of Set 5 | coquimbo
# Processing Record 11 of Set 5 | muros
# Processing Record 12 of Set 5 | kemi
# Processing Record 13 of Set 5 | kemijarvi
# Processing Record 14 of Set 5 | salym
# Processing Record 15 of Set 5 | monroe
# Processing Record 16 of Set 5 | makinsk
# Processing Record 17 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 5 | aykino
# Processing Record 19 of Set 5 | sinnamary
# Processing Record 20 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 22 of Set 5 | neuquen
# Processing Record 23 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 24 of Set 5 | gamba
# Processing Record 25 of Set 5 | bayji
# Processing Record 26 of Set 5 | krasnogorodsk
# Processing Record 27 of Set 5 | awbari
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | nhlangano
# Processing Record 30 of Set 5 | yarada
# Processing Record 31 of Set 5 | yarmouth
# Processing Record 32 of Set 5 | kamenka
# Processing Record 33 of Set 5 | klaksvik
# Processing Record 34 of Set 5 | pilar do sul
# Processing Record 35 of Set 5 | ikom
# Processing Record 36 of Set 5 | camana
# Processing Record 37 of Set 5 | mpika
# Processing Record 38 of Set 5 | puerto ayacucho
# Processing Record 39 of Set 5 | kulhudhuffushi
# Processing Record 40 of Set 5 | novo lino
# Processing Record 41 of Set 5 | ust-koksa
# Processing Record 42 of Set 5 | saint-pierre
# Processing Record 43 of Set 5 | trairi
# Processing Record 44 of Set 5 | saint-francois
# Processing Record 45 of Set 5 | cowansville
# Processing Record 46 of Set 5 | nurota
# Processing Record 47 of Set 5 | richards bay
# Processing Record 48 of Set 5 | ilhabela
# Processing Record 49 of Set 5 | walvis bay
# Processing Record 50 of Set 5 | rocha
# Processing Record 1 of Set 6 | xuddur
# Processing Record 2 of Set 6 | znamenskoye
# Processing Record 3 of Set 6 | warah
# Processing Record 4 of Set 6 | zlocieniec
# Processing Record 5 of Set 6 | puno
# Processing Record 6 of Set 6 | mushie
# Processing Record 7 of Set 6 | pangody
# Processing Record 8 of Set 6 | namibe
# Processing Record 9 of Set 6 | la baneza
# Processing Record 10 of Set 6 | matara
# Processing Record 11 of Set 6 | sumbe
# Processing Record 12 of Set 6 | shchuchye
# City not found. Skipping...
# Processing Record 13 of Set 6 | the valley
# Processing Record 14 of Set 6 | maragogi
# Processing Record 15 of Set 6 | lugovoy
# Processing Record 16 of Set 6 | saldanha
# Processing Record 17 of Set 6 | taoudenni
# Processing Record 18 of Set 6 | beliator
# Processing Record 19 of Set 6 | saint-augustin
# Processing Record 20 of Set 6 | harper
# Processing Record 21 of Set 6 | kattivakkam
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | tahoua
# Processing Record 24 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 6 | bengkulu
# Processing Record 26 of Set 6 | warmbad
# Processing Record 27 of Set 6 | mizque
# Processing Record 28 of Set 6 | salalah
# Processing Record 29 of Set 6 | buchanan
# Processing Record 30 of Set 6 | mangai
# Processing Record 31 of Set 6 | podyuga
# Processing Record 32 of Set 6 | belyy gorodok
# Processing Record 33 of Set 6 | tabou
# Processing Record 34 of Set 6 | tanout
# Processing Record 35 of Set 6 | gat
# Processing Record 36 of Set 6 | mpanda
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | rio grande
# Processing Record 39 of Set 6 | zanjan
# Processing Record 40 of Set 6 | praia
# Processing Record 41 of Set 6 | shakawe
# Processing Record 42 of Set 6 | san carlos de bariloche
# Processing Record 43 of Set 6 | filingue
# Processing Record 44 of Set 6 | storsteinnes
# Processing Record 45 of Set 6 | ivanishchi
# Processing Record 46 of Set 6 | nantucket
# Processing Record 47 of Set 6 | bathsheba
# Processing Record 48 of Set 6 | ancud
# Processing Record 49 of Set 6 | birao
# Processing Record 50 of Set 6 | oktyabrskiy
# Processing Record 1 of Set 7 | kalmunai
# Processing Record 2 of Set 7 | mweka
# Processing Record 3 of Set 7 | westport
# Processing Record 4 of Set 7 | harnosand
# Processing Record 5 of Set 7 | dhrangadhra
# Processing Record 6 of Set 7 | yanam
# Processing Record 7 of Set 7 | boende
# Processing Record 8 of Set 7 | quatre cocos
# Processing Record 9 of Set 7 | marmarion
# Processing Record 10 of Set 7 | spas
# Processing Record 11 of Set 7 | kayes
# Processing Record 12 of Set 7 | dire
# Processing Record 13 of Set 7 | hofn
# Processing Record 14 of Set 7 | santa cruz de la palma
# Processing Record 15 of Set 7 | tavda
# Processing Record 16 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 17 of Set 7 | nioki
# Processing Record 18 of Set 7 | himora
# City not found. Skipping...
# Processing Record 19 of Set 7 | biabou
# Processing Record 20 of Set 7 | grootfontein
# Processing Record 21 of Set 7 | kurchum
# Processing Record 22 of Set 7 | alenquer
# Processing Record 23 of Set 7 | yefira
# City not found. Skipping...
# Processing Record 24 of Set 7 | modasa
# Processing Record 25 of Set 7 | tsabong
# Processing Record 26 of Set 7 | galashki
# Processing Record 27 of Set 7 | grindavik
# Processing Record 28 of Set 7 | ostrovnoy
# Processing Record 29 of Set 7 | binga
# Processing Record 30 of Set 7 | ginda
# Processing Record 31 of Set 7 | najran
# Processing Record 32 of Set 7 | zaysan
# Processing Record 33 of Set 7 | piacabucu
# Processing Record 34 of Set 7 | urcos
# Processing Record 35 of Set 7 | abiy adi
# City not found. Skipping...
# Processing Record 36 of Set 7 | nikolskoye
# Processing Record 37 of Set 7 | sambava
# Processing Record 38 of Set 7 | san andres
# Processing Record 39 of Set 7 | altay
# Processing Record 40 of Set 7 | abu kamal
# Processing Record 41 of Set 7 | elat
# Processing Record 42 of Set 7 | hambantota
# Processing Record 43 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 7 | pinhao
# Processing Record 45 of Set 7 | panama city
# Processing Record 46 of Set 7 | riyadh
# Processing Record 47 of Set 7 | veraval
# Processing Record 48 of Set 7 | khangarh
# Processing Record 49 of Set 7 | weingarten
# Processing Record 50 of Set 7 | quelimane
# Processing Record 1 of Set 8 | caetite
# Processing Record 2 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 8 | bouar
# Processing Record 4 of Set 8 | brunsbuttel
# Processing Record 5 of Set 8 | waverly
# Processing Record 6 of Set 8 | khanpur
# Processing Record 7 of Set 8 | sochi
# Processing Record 8 of Set 8 | camacha
# Processing Record 9 of Set 8 | gilgit
# Processing Record 10 of Set 8 | cotonou
# Processing Record 11 of Set 8 | sao luiz gonzaga
# Processing Record 12 of Set 8 | port-gentil
# Processing Record 13 of Set 8 | boca do acre
# Processing Record 14 of Set 8 | oloron-sainte-marie
# Processing Record 15 of Set 8 | ekibastuz
# Processing Record 16 of Set 8 | lethem
# Processing Record 17 of Set 8 | herat
# Processing Record 18 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 8 | ulagan
# Processing Record 20 of Set 8 | samana
# Processing Record 21 of Set 8 | atlantis
# Processing Record 22 of Set 8 | sao francisco de paula
# Processing Record 23 of Set 8 | morlaix
# Processing Record 24 of Set 8 | tapioszecso
# Processing Record 25 of Set 8 | mbanza-ngungu
# Processing Record 26 of Set 8 | salaverry
# Processing Record 27 of Set 8 | sao desiderio
# Processing Record 28 of Set 8 | matagami
# Processing Record 29 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 8 | sal rei
# Processing Record 31 of Set 8 | mwene-ditu
# Processing Record 32 of Set 8 | rawson
# Processing Record 33 of Set 8 | bilma
# Processing Record 34 of Set 8 | algiers
# Processing Record 35 of Set 8 | dzaoudzi
# Processing Record 36 of Set 8 | cayenne
# Processing Record 37 of Set 8 | ust-tsilma
# Processing Record 38 of Set 8 | inhambane
# Processing Record 39 of Set 8 | panaba
# Processing Record 40 of Set 8 | ghanzi
# Processing Record 41 of Set 8 | cambridge
# Processing Record 42 of Set 8 | parauna
# Processing Record 43 of Set 8 | gari
# Processing Record 44 of Set 8 | ntcheu
# Processing Record 45 of Set 8 | sisimiut
# Processing Record 46 of Set 8 | pokhara
# Processing Record 47 of Set 8 | ambam
# Processing Record 48 of Set 8 | syumsi
# Processing Record 49 of Set 8 | carnarvon
# Processing Record 50 of Set 8 | napanee
# Processing Record 1 of Set 9 | chapais
# Processing Record 2 of Set 9 | lamu
# Processing Record 3 of Set 9 | tombouctou
# Processing Record 4 of Set 9 | la macarena
# Processing Record 5 of Set 9 | vestmannaeyjar
# Processing Record 6 of Set 9 | tete
# Processing Record 7 of Set 9 | huarmey
# Processing Record 8 of Set 9 | gao
# Processing Record 9 of Set 9 | ascension
# Processing Record 10 of Set 9 | sur
# Processing Record 11 of Set 9 | thunder bay
# Processing Record 12 of Set 9 | burbach
# Processing Record 13 of Set 9 | vichy
# Processing Record 14 of Set 9 | sao raimundo das mangabeiras
# Processing Record 15 of Set 9 | novo aripuana
# Processing Record 16 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 17 of Set 9 | mangan
# Processing Record 18 of Set 9 | komsomolets
# Processing Record 19 of Set 9 | vestmanna
# Processing Record 20 of Set 9 | abu dhabi
# Processing Record 21 of Set 9 | bolshaya glushitsa
# Processing Record 22 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 23 of Set 9 | soma
# Processing Record 24 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 25 of Set 9 | oranjestad
# Processing Record 26 of Set 9 | gormi
# City not found. Skipping...
# Processing Record 27 of Set 9 | mitu
# Processing Record 28 of Set 9 | peno
# Processing Record 29 of Set 9 | bonavista
# Processing Record 30 of Set 9 | lagdo
# Processing Record 31 of Set 9 | malindi
# Processing Record 32 of Set 9 | capinopolis
# Processing Record 33 of Set 9 | baripada
# Processing Record 34 of Set 9 | kondagaon
# Processing Record 35 of Set 9 | temiscaming
# Processing Record 36 of Set 9 | takoradi
# Processing Record 37 of Set 9 | turukhansk
# Processing Record 38 of Set 9 | jaru
# Processing Record 39 of Set 9 | dhidhdhoo
# Processing Record 40 of Set 9 | sadovoye
# Processing Record 41 of Set 9 | maroantsetra
# Processing Record 42 of Set 9 | ugoofaaru
# Processing Record 43 of Set 9 | correntina
# Processing Record 44 of Set 9 | albany
# Processing Record 45 of Set 9 | calama
# Processing Record 46 of Set 9 | trincomalee
# Processing Record 47 of Set 9 | keith
# Processing Record 48 of Set 9 | sakakah
# Processing Record 49 of Set 9 | saint-georges
# Processing Record 50 of Set 9 | maridi
# Processing Record 1 of Set 10 | siirt
# Processing Record 2 of Set 10 | amla
# Processing Record 3 of Set 10 | soyo
# Processing Record 4 of Set 10 | murmashi
# Processing Record 5 of Set 10 | haguenau
# Processing Record 6 of Set 10 | korla
# Processing Record 7 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 10 | penzance
# Processing Record 9 of Set 10 | severnyy
# Processing Record 10 of Set 10 | coihaique
# Processing Record 11 of Set 10 | sainte-maxime
# Processing Record 12 of Set 10 | maraa
# Processing Record 13 of Set 10 | canutama
# Processing Record 14 of Set 10 | tshikapa
# Processing Record 15 of Set 10 | ardakan
# Processing Record 16 of Set 10 | taltal
# Processing Record 17 of Set 10 | le port
# Processing Record 18 of Set 10 | andreapol
# Processing Record 19 of Set 10 | traverse city
# Processing Record 20 of Set 10 | diego de almagro
# Processing Record 21 of Set 10 | izamal
# Processing Record 22 of Set 10 | kotido
# Processing Record 23 of Set 10 | kolyshley
# Processing Record 24 of Set 10 | talawdi
# City not found. Skipping...
# Processing Record 25 of Set 10 | lodwar
# Processing Record 26 of Set 10 | amalapuram
# Processing Record 27 of Set 10 | caucaia
# Processing Record 28 of Set 10 | east linton
# Processing Record 29 of Set 10 | jumla
# Processing Record 30 of Set 10 | akdepe
# Processing Record 31 of Set 10 | nicoya
# Processing Record 32 of Set 10 | mirabad
# Processing Record 33 of Set 10 | masuguru
# Processing Record 34 of Set 10 | naenwa
# City not found. Skipping...
# Processing Record 35 of Set 10 | mamlyutka
# Processing Record 36 of Set 10 | mehamn
# Processing Record 37 of Set 10 | puerto baquerizo moreno
# Processing Record 38 of Set 10 | inirida
# Processing Record 39 of Set 10 | normandin
# Processing Record 40 of Set 10 | annau
# Processing Record 41 of Set 10 | mbekenyera
# Processing Record 42 of Set 10 | bolshoye selo
# Processing Record 43 of Set 10 | bissau
# Processing Record 44 of Set 10 | mezen
# Processing Record 45 of Set 10 | mollendo
# Processing Record 46 of Set 10 | khormuj
# City not found. Skipping...
# Processing Record 47 of Set 10 | urazovo
# Processing Record 48 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 49 of Set 10 | lanivtsi
# Processing Record 50 of Set 10 | tsaratanana
# Processing Record 1 of Set 11 | port hope
# Processing Record 2 of Set 11 | kontagora
# Processing Record 3 of Set 11 | rosoman
# Processing Record 4 of Set 11 | presidencia roque saenz pena
# Processing Record 5 of Set 11 | achisay
# City not found. Skipping...
# Processing Record 6 of Set 11 | yei
# Processing Record 7 of Set 11 | kyrylivka
# Processing Record 8 of Set 11 | varangaon
# Processing Record 9 of Set 11 | santa rosa
# Processing Record 10 of Set 11 | lagoa
# Processing Record 11 of Set 11 | lasa
# Processing Record 12 of Set 11 | grand gaube
# Processing Record 13 of Set 11 | great yarmouth
# Processing Record 14 of Set 11 | havoysund
# Processing Record 15 of Set 11 | mudyuga
# City not found. Skipping...
# Processing Record 16 of Set 11 | umm kaddadah
# Processing Record 17 of Set 11 | bria
# Processing Record 18 of Set 11 | havelock
# Processing Record 19 of Set 11 | roald
# Processing Record 20 of Set 11 | abha
# Processing Record 21 of Set 11 | galle
# Processing Record 22 of Set 11 | sainte-marie
# Processing Record 23 of Set 11 | mahanoro
# Processing Record 24 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 11 | kisangani
# Processing Record 26 of Set 11 | mumford
# Processing Record 27 of Set 11 | ayagoz
# Processing Record 28 of Set 11 | volodarskiy
# Processing Record 29 of Set 11 | guelengdeng
# City not found. Skipping...
# Processing Record 30 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 11 | pori
# Processing Record 32 of Set 11 | marzuq
# Processing Record 33 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 34 of Set 11 | novopokrovka
# Processing Record 35 of Set 11 | telimele
# Processing Record 36 of Set 11 | areosa
# Processing Record 37 of Set 11 | cabo rojo
# Processing Record 38 of Set 11 | makurdi
# Processing Record 39 of Set 11 | blagoyevo
# Processing Record 40 of Set 11 | eregli
# Processing Record 41 of Set 11 | farafangana
# Processing Record 42 of Set 11 | sabha
# Processing Record 43 of Set 11 | muravlenko
# Processing Record 44 of Set 11 | nuuk
# Processing Record 45 of Set 11 | sharjah
# Processing Record 46 of Set 11 | ornskoldsvik
# Processing Record 47 of Set 11 | jand
# Processing Record 48 of Set 11 | oriximina
# Processing Record 49 of Set 11 | novo cruzeiro
# Processing Record 50 of Set 11 | ladario
# Processing Record 1 of Set 12 | san pedro del pinatar
# Processing Record 2 of Set 12 | parana
# Processing Record 3 of Set 12 | mugumu
# Processing Record 4 of Set 12 | baglung
# Processing Record 5 of Set 12 | nandigama
# Processing Record 6 of Set 12 | saquena
# Processing Record 7 of Set 12 | belyy yar
# Processing Record 8 of Set 12 | kjopsvik
# Processing Record 9 of Set 12 | sunndalsora
# Processing Record 10 of Set 12 | sabibah
# City not found. Skipping...
# Processing Record 11 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 12 of Set 12 | alvares machado
# Processing Record 13 of Set 12 | atyrau
# Processing Record 14 of Set 12 | puerto colombia
# Processing Record 15 of Set 12 | chiredzi
# Processing Record 16 of Set 12 | macherla
# Processing Record 17 of Set 12 | ighiu
# Processing Record 18 of Set 12 | kikuyu
# Processing Record 19 of Set 12 | lenzing
# Processing Record 20 of Set 12 | kolpashevo
# Processing Record 21 of Set 12 | kismayo
# Processing Record 22 of Set 12 | dobroye
# Processing Record 23 of Set 12 | les herbiers
# Processing Record 24 of Set 12 | aksu
# Processing Record 25 of Set 12 | beyneu
# Processing Record 26 of Set 12 | san pedro
# Processing Record 27 of Set 12 | boralday
# Processing Record 28 of Set 12 | puerto pinasco
# City not found. Skipping...
# Processing Record 29 of Set 12 | salta
# Processing Record 30 of Set 12 | teguldet
# Processing Record 31 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 12 | kutum
# Processing Record 33 of Set 12 | nador
# Processing Record 34 of Set 12 | laguna
# Processing Record 35 of Set 12 | cazaje
# City not found. Skipping...
# Processing Record 36 of Set 12 | verkh-chebula
# Processing Record 37 of Set 12 | tocopilla
# Processing Record 38 of Set 12 | horsens
# Processing Record 39 of Set 12 | vilhena
# Processing Record 40 of Set 12 | wattegama
# Processing Record 41 of Set 12 | rorvik
# Processing Record 42 of Set 12 | lerwick
# Processing Record 43 of Set 12 | levokumskoye
# Processing Record 44 of Set 12 | puerto ayora
# Processing Record 45 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 12 | sarmanovo
# Processing Record 47 of Set 12 | karlskrona
# Processing Record 48 of Set 12 | san jose
# Processing Record 49 of Set 12 | birjand
# Processing Record 50 of Set 12 | qasigiannguit
# Processing Record 1 of Set 13 | dabakala
# Processing Record 2 of Set 13 | kuzovatovo
# Processing Record 3 of Set 13 | la romana
# Processing Record 4 of Set 13 | japura
# Processing Record 5 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 13 | bom jesus
# Processing Record 7 of Set 13 | senador jose porfirio
# Processing Record 8 of Set 13 | brae
# Processing Record 9 of Set 13 | mosquera
# Processing Record 10 of Set 13 | doka
# Processing Record 11 of Set 13 | banda aceh
# Processing Record 12 of Set 13 | daloa
# Processing Record 13 of Set 13 | cape coast
# Processing Record 14 of Set 13 | dwarka
# Processing Record 15 of Set 13 | bloomington
# Processing Record 16 of Set 13 | nadvoitsy
# Processing Record 17 of Set 13 | vallenar
# Processing Record 18 of Set 13 | andra
# Processing Record 19 of Set 13 | kavaratti
# Processing Record 20 of Set 13 | sistranda
# Processing Record 21 of Set 13 | san juan de la maguana
# Processing Record 22 of Set 13 | tayzhina
# Processing Record 23 of Set 13 | doha
# Processing Record 24 of Set 13 | moron
# Processing Record 25 of Set 13 | misratah
# Processing Record 26 of Set 13 | iberia
# Processing Record 27 of Set 13 | kochi
# Processing Record 28 of Set 13 | sibi
# Processing Record 29 of Set 13 | sarakhs
# Processing Record 30 of Set 13 | aasiaat
# Processing Record 31 of Set 13 | burica
# City not found. Skipping...
# Processing Record 32 of Set 13 | mount darwin
# Processing Record 33 of Set 13 | ikalamavony
# Processing Record 34 of Set 13 | arica
# Processing Record 35 of Set 13 | kristiinankaupunki
# Processing Record 36 of Set 13 | kalmar
# Processing Record 37 of Set 13 | matelandia
# Processing Record 38 of Set 13 | rankweil
# Processing Record 39 of Set 13 | ciudad real
# Processing Record 40 of Set 13 | shetpe
# Processing Record 41 of Set 13 | amherst
# Processing Record 42 of Set 13 | mananara
# Processing Record 43 of Set 13 | balkhash
# Processing Record 44 of Set 13 | valdosta
# Processing Record 45 of Set 13 | visnes
# Processing Record 46 of Set 13 | tignere
# Processing Record 47 of Set 13 | disna
# Processing Record 48 of Set 13 | lakhna
# Processing Record 49 of Set 13 | ushtobe
# Processing Record 50 of Set 13 | jizan
# Processing Record 1 of Set 14 | sakhnovshchyna
# Processing Record 2 of Set 14 | carballo
# Processing Record 3 of Set 14 | moose factory
# Processing Record 4 of Set 14 | chone
# Processing Record 5 of Set 14 | agadir
# Processing Record 6 of Set 14 | sorland
# Processing Record 7 of Set 14 | yerazgavors
# Processing Record 8 of Set 14 | henties bay
# Processing Record 9 of Set 14 | malaya purga
# Processing Record 10 of Set 14 | honningsvag
# Processing Record 11 of Set 14 | olinda
# Processing Record 12 of Set 14 | sechura
# Processing Record 13 of Set 14 | port-cartier
# Processing Record 14 of Set 14 | omemee
# Processing Record 15 of Set 14 | daman
# Processing Record 16 of Set 14 | hobyo
# Processing Record 17 of Set 14 | bafoulabe
# Processing Record 18 of Set 14 | union city
# Processing Record 19 of Set 14 | puerto carreno
# Processing Record 20 of Set 14 | shache
# Processing Record 21 of Set 14 | baranchinskiy
# Processing Record 22 of Set 14 | nizwa
# Processing Record 23 of Set 14 | kachiry
# Processing Record 24 of Set 14 | havre-saint-pierre
# Processing Record 25 of Set 14 | nassau
# Processing Record 26 of Set 14 | kempele
# Processing Record 27 of Set 14 | jeremie
# Processing Record 28 of Set 14 | vitoria da conquista
# Processing Record 29 of Set 14 | mormugao
# Processing Record 30 of Set 14 | setermoen
# Processing Record 31 of Set 14 | imbituba
# Processing Record 32 of Set 14 | kovdor
# Processing Record 33 of Set 14 | baijiantan
# Processing Record 34 of Set 14 | gobabis
# Processing Record 35 of Set 14 | gambela
# Processing Record 36 of Set 14 | navabad
# City not found. Skipping...
# Processing Record 37 of Set 14 | kreminna
# Processing Record 38 of Set 14 | bubaque
# Processing Record 39 of Set 14 | seminole
# Processing Record 40 of Set 14 | mansa
# Processing Record 41 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 14 | goderich
# Processing Record 43 of Set 14 | urengoy
# Processing Record 44 of Set 14 | tiznit
# Processing Record 45 of Set 14 | myre
# Processing Record 46 of Set 14 | bayshore gardens
# Processing Record 47 of Set 14 | mecca
# Processing Record 48 of Set 14 | ouango
# Processing Record 49 of Set 14 | baglan
# Processing Record 50 of Set 14 | ascope
# Processing Record 1 of Set 15 | ouadda
# Processing Record 2 of Set 15 | chiriqui grande
# Processing Record 3 of Set 15 | chishtian mandi
# Processing Record 4 of Set 15 | challapata
# Processing Record 5 of Set 15 | elizabeth city
# Processing Record 6 of Set 15 | arboletes
# Processing Record 7 of Set 15 | crab hill
# City not found. Skipping...
# Processing Record 8 of Set 15 | tazovskiy
# Processing Record 9 of Set 15 | kyshtovka
# Processing Record 10 of Set 15 | chirongui
# Processing Record 11 of Set 15 | abancay
# Processing Record 12 of Set 15 | den helder
# Processing Record 13 of Set 15 | kant
# Processing Record 14 of Set 15 | tucuman
# Processing Record 15 of Set 15 | basoko
# Processing Record 16 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 17 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 18 of Set 15 | nivala
# Processing Record 19 of Set 15 | mattru
# Processing Record 20 of Set 15 | kaz
# Processing Record 21 of Set 15 | jardim
# Processing Record 22 of Set 15 | clarence town
# Processing Record 23 of Set 15 | vagur
# Processing Record 24 of Set 15 | ronne
# Processing Record 25 of Set 15 | wilmington
# Processing Record 26 of Set 15 | mahroni
# Processing Record 27 of Set 15 | ijui
# Processing Record 28 of Set 15 | langarud
# Processing Record 29 of Set 15 | tres arroyos
# Processing Record 30 of Set 15 | iquique
# Processing Record 31 of Set 15 | filadelfia
# Processing Record 32 of Set 15 | edgewater
# Processing Record 33 of Set 15 | patacamaya
# Processing Record 34 of Set 15 | puerto boyaca
# Processing Record 35 of Set 15 | grimari
# City not found. Skipping...
# Processing Record 36 of Set 15 | pemba
# Processing Record 37 of Set 15 | aksarka
# Processing Record 38 of Set 15 | racine
# Processing Record 39 of Set 15 | atlantic beach
# Processing Record 40 of Set 15 | mayumba
# Processing Record 41 of Set 15 | qaqortoq
# Processing Record 42 of Set 15 | jadu
# Processing Record 43 of Set 15 | khanino
# Processing Record 44 of Set 15 | zhanaozen
# Processing Record 45 of Set 15 | salinopolis
# Processing Record 46 of Set 15 | agirish
# Processing Record 47 of Set 15 | usinsk
# Processing Record 48 of Set 15 | zonguldak
# Processing Record 49 of Set 15 | kosa
# Processing Record 50 of Set 15 | shubarshi
# Processing Record 1 of Set 16 | mahbubabad
# Processing Record 2 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 16 | sarkikaraagac
# Processing Record 4 of Set 16 | rosario oeste
# Processing Record 5 of Set 16 | bosaso
# Processing Record 6 of Set 16 | livramento
# Processing Record 7 of Set 16 | tukrah
# Processing Record 8 of Set 16 | ampanihy
# Processing Record 9 of Set 16 | abaete
# Processing Record 10 of Set 16 | peniche
# Processing Record 11 of Set 16 | omboue
# Processing Record 12 of Set 16 | aswan
# Processing Record 13 of Set 16 | yining
# Processing Record 14 of Set 16 | bababe
# City not found. Skipping...
# Processing Record 15 of Set 16 | tessalit
# Processing Record 16 of Set 16 | nanded
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0        Hermanus -34.4187   19.2345     77.81        86          96
# 1       Mahebourg -20.4081   57.7000     82.26        79          90
# 2      Porto Novo   6.4965    2.6036     73.17        88          56
# 3           Bayan  46.0833  127.4000      9.68        75         100
# 4  Saint-Philippe -21.3585   55.7679     83.79        84         100
# 5      Malkangiri  18.3500   81.9000     86.81        33           0
# 6       Jamestown  42.0970  -79.2353     38.01        75         100
# 7    Kruisfontein -34.0033   24.7314     75.88        50          99
# 8   Saint Anthony  45.0205  -93.2180     34.25        88         100
# 9          Ulundi -28.3352   31.4162     77.29        64         100
#
#    Wind Speed                                            Country  \
# 0        2.68  {'coord': {'lon': 19.2345, 'lat': -34.4187}, '...
# 1       19.60  {'coord': {'lon': 57.7, 'lat': -20.4081}, 'wea...
# 2        3.02  {'coord': {'lon': 2.6036, 'lat': 6.4965}, 'wea...
# 3        8.81  {'coord': {'lon': 127.4, 'lat': 46.0833}, 'wea...
# 4       15.50  {'coord': {'lon': 55.7679, 'lat': -21.3585}, '...
# 5        1.36  {'coord': {'lon': 81.9, 'lat': 18.35}, 'weathe...
# 6       10.36  {'coord': {'lon': -79.2353, 'lat': 42.097}, 'w...
# 7        2.59  {'coord': {'lon': 24.7314, 'lat': -34.0033}, '...
# 8        8.05  {'coord': {'lon': -93.218, 'lat': 45.0205}, 'w...
# 9        5.10  {'coord': {'lon': 31.4162, 'lat': -28.3352}, '...
#
#   Weather Description
# 0     overcast clouds
# 1          light rain
# 2       broken clouds
# 3     overcast clouds
# 4          light rain
# 5           clear sky
# 6          light rain
# 7     overcast clouds
# 8     overcast clouds
# 9     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max_Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max_Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Recreate the DataFrame by using the new column order
df = city_data_df[new_column_order]

# Display sample data
df.head(10)
# Out:
#              City                                            Country      Lat  \
# 0        Hermanus  {'coord': {'lon': 19.2345, 'lat': -34.4187}, '... -34.4187
# 1       Mahebourg  {'coord': {'lon': 57.7, 'lat': -20.4081}, 'wea... -20.4081
# 2      Porto Novo  {'coord': {'lon': 2.6036, 'lat': 6.4965}, 'wea...   6.4965
# 3           Bayan  {'coord': {'lon': 127.4, 'lat': 46.0833}, 'wea...  46.0833
# 4  Saint-Philippe  {'coord': {'lon': 55.7679, 'lat': -21.3585}, '... -21.3585
# 5      Malkangiri  {'coord': {'lon': 81.9, 'lat': 18.35}, 'weathe...  18.3500
# 6       Jamestown  {'coord': {'lon': -79.2353, 'lat': 42.097}, 'w...  42.0970
# 7    Kruisfontein  {'coord': {'lon': 24.7314, 'lat': -34.0033}, '... -34.0033
# 8   Saint Anthony  {'coord': {'lon': -93.218, 'lat': 45.0205}, 'w...  45.0205
# 9          Ulundi  {'coord': {'lon': 31.4162, 'lat': -28.3352}, '... -28.3352
#
#         Lng  Max_Temp  Humidity  Cloudiness  Wind Speed Weather Description
# 0   19.2345     77.81        86          96        2.68     overcast clouds
# 1   57.7000     82.26        79          90       19.60          light rain
# 2    2.6036     73.17        88          56        3.02       broken clouds
# 3  127.4000      9.68        75         100        8.81     overcast clouds
# 4   55.7679     83.79        84         100       15.50          light rain
# 5   81.9000     86.81        33           0        1.36           clear sky
# 6  -79.2353     38.01        75         100       10.36          light rain
# 7   24.7314     75.88        50          99        2.59     overcast clouds
# 8  -93.2180     34.25        88         100        8.05     overcast clouds
# 9   31.4162     77.29        64         100        5.10     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max_Temp  Humidity  Cloudiness  \
# 0        Hermanus -34.4187   19.2345     77.81        86          96
# 1       Mahebourg -20.4081   57.7000     82.26        79          90
# 2      Porto Novo   6.4965    2.6036     73.17        88          56
# 3           Bayan  46.0833  127.4000      9.68        75         100
# 4  Saint-Philippe -21.3585   55.7679     83.79        84         100
# 5      Malkangiri  18.3500   81.9000     86.81        33           0
# 6       Jamestown  42.0970  -79.2353     38.01        75         100
# 7    Kruisfontein -34.0033   24.7314     75.88        50          99
# 8   Saint Anthony  45.0205  -93.2180     34.25        88         100
# 9          Ulundi -28.3352   31.4162     77.29        64         100
#
#    Wind Speed                                            Country  \
# 0        2.68  {'coord': {'lon': 19.2345, 'lat': -34.4187}, '...
# 1       19.60  {'coord': {'lon': 57.7, 'lat': -20.4081}, 'wea...
# 2        3.02  {'coord': {'lon': 2.6036, 'lat': 6.4965}, 'wea...
# 3        8.81  {'coord': {'lon': 127.4, 'lat': 46.0833}, 'wea...
# 4       15.50  {'coord': {'lon': 55.7679, 'lat': -21.3585}, '...
# 5        1.36  {'coord': {'lon': 81.9, 'lat': 18.35}, 'weathe...
# 6       10.36  {'coord': {'lon': -79.2353, 'lat': 42.097}, 'w...
# 7        2.59  {'coord': {'lon': 24.7314, 'lat': -34.0033}, '...
# 8        8.05  {'coord': {'lon': -93.218, 'lat': 45.0205}, 'w...
# 9        5.10  {'coord': {'lon': 31.4162, 'lat': -28.3352}, '...
#
#   Weather Description
# 0     overcast clouds
# 1          light rain
# 2       broken clouds
# 3     overcast clouds
# 4          light rain
# 5           clear sky
# 6          light rain
# 7     overcast clouds
# 8     overcast clouds
# 9     overcast clouds

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
